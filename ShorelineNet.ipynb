# %% [markdown]
# ### About
#
# This notebooks trains an image segementation network with modified MobileNetV3 + UNet structure on the full MaSTr1325 dataset. The results are preliminarily evaluated based on a shoreline per-pixel accuracy, and subsequently exported and evaluated separately in MATLAB.
#
# ```
# Dataset   : 'mastr.zip'
#                 1325 images
#
# Labels
#   Obstacles and environment = 0
#   Water = 1
#   Sky = 2
#   Ignore region / unknown category = 4
#
# X: ? x 384 x 512 x 3 .png files
# y: ? x 384 x 512     .png files
# ```
#
# Note that this script was originally ran in google colab and processed dataset is loaded from the drive. You can recreate the workflow by following documentations below
#
# Find evaluation code here:  https://github.com/bborja/modd
#
# Find dataset here: https://box.vicos.si/borja/viamaro/index.html
#
# We kindly ask you to cite our papers if you use the provided code below.
#
# ```
# @inproceedings{yao2021shorelinenet,
#   title={ShorelineNet: An Efficient Deep Learning Approach for Shoreline Semantic Segmentation for Unmanned Surface Vehicles},
#   author={Yao, Linghong and Kanoulas, Dimitrios and Ji, Ze and Liu, Yuanchang},
#   booktitle={Proceedings of the... IEEE/RSJ International Conference on Intelligent Robots and Systems. IEEE/RSJ International Conference on Intelligent Robots and Systems},
#   year={2021},
#   organization={IEEE}
# }
# ```

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Imports & Installs

# %%
# Install tfds-nightly for upsampling layer
# !pip install -q git+https://github.com/tensorflow/examples.git
# !pip install -q -U tfds-nightly
# Install tfa for transformations
# !pip install -q -U tensorflow-addons
# Out:
#   Building wheel for tensorflow-examples (setup.py) ... done
#      |████████████████████████████████| 3.8MB 7.3MB/s
#      |████████████████████████████████| 706kB 8.4MB/s

# %%
import os
import re
import random
import time
import math
import datetime

import tensorflow as tf
import tensorflow_addons as tfa

import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd

from PIL import Image as pimage 
from IPython.display import clear_output
from tensorflow_examples.models.pix2pix import pix2pix

from tqdm.notebook import tqdm

AUTOTUNE = tf.data.experimental.AUTOTUNE

# %% [markdown]
# ### Load data from google drive

# %% [markdown]
# **MasTr Dataset**

# %%
if 'data' not in os.listdir():
  # !cp "/content/drive/My Drive/project_online/dataset/mastr.zip" .
  # !unzip -q 'mastr.zip' -d data
  # !rm 'mastr.zip'

# %% [markdown]
# ```
# data
#   - masks
#   - images
#
# Image names:
#   0001.jpg
#   384 x 512 x 3
# Annotation image names:
#   0001m.png
#   384 x 512 x 1 (0: obstacle, 1: water, 2: sky)
# ```

# %% [markdown]
# **MODD2 Dataset**

# %%
# Footage 1 to 28, used to export prediction & evaluate in MATLAB
if 'eval_data' not in os.listdir():
  # !cp "/content/drive/My Drive/project_online/dataset/eval_data_highres.zip" .
  # !unzip -q 'eval_data_highres.zip' -d eval_data
  # !rm 'eval_data_highres.zip'

# %% [markdown]
# ```
# eval_data
#   - images
#   - masks
#
# Image names:
#   27_001.jpg
#   128 x 128 x 3
# Annotation image names:
#   27_001m.png
#   128 x 128 x 1 (background-pixel = 0, sea-pixel = 1)
# ```

# %% [markdown]
# ### Dataset Pipeline - functions
#
# 1. `list_files`: get file names from directory
# 2. `parse_image` : loads image & its corresponding label
# 3. `load_image_train` and `load_image_test`: augmentation & normalize
# 4. `configure_ds`: cache, batch, and prefetch

# %%
def parse_image(img_path: str) -> dict:
    '''
    Loads the image and its mask, returns a dictionary

    Original      Returns
    0: obstacle   0: obstacle
    1: water      1: water
    2: sky        2: sky
    4: unknown    3: unknown

    Args
    ----------
    img_path : str
        Image filename pattern (glob)
        (Mask location is found using regex)

    Returns
    ----------
    dict {'image': tensor (384 x 512 x 3), 'mask': tensor (384 x 512 x 3)}
        Dictionary mapping an image and its annotation.
    '''
    
    image = tf.io.read_file(img_path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.convert_image_dtype(image, tf.dtypes.uint8)

    # For one Image path:
    # .../data/images/train/01_001.png
    # Its corresponding annotation path is:
    # .../data/annotations/train/01_001_label.png
    mask_path = tf.strings.regex_replace(img_path, "images", "masks")
    mask_path = tf.strings.regex_replace(mask_path, ".jpg", "m.png")

    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_png(mask, channels=1, dtype=tf.dtypes.uint8) #+ 1
    mask = tf.where(mask == 4, np.dtype('uint8').type(3), mask)
    # mask = tf.where(mask == 5, float(nan), mask )

    return {'image': image, 'mask': mask}

# %%
def normalize(input_image: tf.Tensor, input_mask: tf.Tensor) -> tuple:
    '''
    Rescale the pixel values of the images from [0, 255] to [0, 1]

    Args
    ----------
    input_image : tf.Tensor
        Tensorflow tensor containing an image of size [384,512,3].
    input_mask : tf.Tensor
        Tensorflow tensor containing an annotation of size [384,512,1].

    Returns
    ----------
    tuple
        Normalized image and its annotation.
    '''

    input_image = tf.cast(input_image, tf.float32) / 255.0
    input_mask = tf.cast(input_mask, tf.float32)
    return input_image, input_mask

# %%
def load_image_train(datapoint: dict) -> tuple:
    '''
    Apply some transformations to an input dictionary
    containing an image and its annotation.

    Note: should be applying to training set only

    Args
    ----------
    datapoint : dict
        A dict containing an image and its annotation.

    Returns
    ----------
    tuple
        A modified image and its annotation.
    '''

    input_image = datapoint['image']
    input_mask = datapoint['mask']
    height, width = 384, 512

    # Flip
    if tf.random.uniform(()) > 0.5:
      input_image = tf.image.flip_left_right(input_image)
      input_mask = tf.image.flip_left_right(input_mask)
    
    # Hue
    if tf.random.uniform(()) > 0.2:
      input_image = tf.image.random_hue(input_image, 0.2)
      input_image = tf.image.random_saturation(input_image, 0.8, 1.2)
      input_image = tf.image.random_contrast(input_image, 0.6, 1.4)
      input_image = tf.image.random_brightness(input_image, 0.2)

    # Rotation
    if tf.random.uniform(()) > 0.2:
      alpha = tf.random.uniform((), -math.pi/8, math.pi/8)
      input_image = tfa.image.rotate(tf.cast(input_image, dtype=tf.int32), alpha)
      input_mask = tfa.image.rotate(tf.cast(input_mask, dtype=tf.int32), alpha, fill_value=3)
      input_image = tf.cast(input_image, dtype=tf.uint8)
      input_mask = tf.cast(input_mask, dtype=tf.uint8)

    # Scaling
    if tf.random.uniform(()) > 0.2:
      crop_width = tf.random.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
      crop_height = tf.random.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)

      offset_x = tf.random.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
      offset_y = tf.random.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

      input_image = tf.image.crop_to_bounding_box(input_image, offset_y, offset_x, crop_height, crop_width)
      input_mask = tf.image.crop_to_bounding_box(input_mask, offset_y, offset_x, crop_height, crop_width)

    # Resize
    input_image = tf.image.resize(input_image, (IMG_SIZE, IMG_SIZE))
    input_mask = tf.image.resize(input_mask, (IMG_SIZE, IMG_SIZE), method='nearest')

    # Normalize & clip
    input_image, input_mask = normalize(input_image, input_mask)
    input_image = tf.clip_by_value(input_image, clip_value_min=0., clip_value_max=1.)

    return input_image, input_mask

# %%
def load_image_test(datapoint: dict) -> tuple:
    '''
    Normalize and resize a test image and its annotation, no augmentation

    Note: 
      Applies to both validation and testing set

    Parameters
    ----------
    datapoint : dict
        A dict containing an image and its annotation.

    Returns
    -------
    tuple
        A modified image and its annotation.
    '''

    # input_image = datapoint['image']
    # input_mask = datapoint['mask']

    # Resize
    input_image = tf.image.resize(datapoint['image'], (IMG_SIZE, IMG_SIZE))
    input_mask = tf.image.resize(datapoint['mask'], (IMG_SIZE, IMG_SIZE))

    # Normalize
    input_image, input_mask = normalize(input_image, input_mask)

    return input_image, input_mask

# %% [markdown]
# ### Dataset Pipeline - execute

# %%
IMG_SIZE = 224
# Batch size is set to 32 in order to see if inference at real time is possible
BATCH_SIZE = 64
N_CLASSES = 3         # 0: obstacle, 1: water, 2: sky
TRAIN_VAL_RATIO = 0.90 # Within the MasTr dataset


# For reproducible result 
SEED = 321
# tf.random.set_seed(SEED)

# %%
data_dir = os.path.join(os.getcwd(), 'data/')
images_path = os.path.join(os.getcwd(), 'data/images/')
labels_path = os.path.join(os.getcwd(), 'data/masks/')

test_data_dir = os.path.join(os.getcwd(), 'data/')
test_images_path = os.path.join(os.getcwd(), 'test_data/images/')
test_labels_path = os.path.join(os.getcwd(), 'test_data/masks/')

eval_data_dir = os.path.join(os.getcwd(), 'eval_data/')
eval_images_path = os.path.join(os.getcwd(), 'eval_data/images/')
eval_labels_path = os.path.join(os.getcwd(), 'eval_data/masks/')

total_image_count = len(os.listdir(images_path))

print('total number of images:      {}'.format(total_image_count))
# Out:
# total number of images:      1325

# %%
# Get list of all image files
list_dir = tf.data.Dataset.list_files(images_path + '*.jpg', shuffle=True, seed=SEED)
# test_ds = tf.data.Dataset.list_files(test_images_path + '*.jpg', shuffle=False)

test_sequence_folders = ['seq27', 'seq28']
eval_ds = tf.data.Dataset.list_files(eval_images_path + 'seq*' + '/*.jpg', shuffle=False) 
test_ds = tf.data.Dataset.list_files([eval_images_path + seq + '/*.jpg' for seq in test_sequence_folders], shuffle=False) 

# # Get list of file names for train and val
train_length = round(total_image_count * TRAIN_VAL_RATIO)
train_ds = list_dir.take(train_length)
val_ds = list_dir.skip(train_length)

# Get length of each dataset
TRAINSET_SIZE = tf.data.experimental.cardinality(train_ds).numpy()
VALSET_SIZE = tf.data.experimental.cardinality(val_ds).numpy()
TEST_SIZE = tf.data.experimental.cardinality(test_ds).numpy()
EVAL_SIZE = tf.data.experimental.cardinality(eval_ds).numpy()

print(f'Train: {TRAINSET_SIZE}, Val: {VALSET_SIZE}, Test: {TEST_SIZE}, Eval: {EVAL_SIZE}')
# Out:
# Train: 1192, Val: 133, Test: 1292, Eval: 11703

# %%
train_ds = train_ds.map(parse_image)
val_ds = val_ds.map(parse_image)
test_ds = test_ds.map(parse_image)
eval_ds = eval_ds.map(parse_image)

# %%
# Training set:
#           cache -> shuffle -> Augment -> batch -> repeat -> prefetch

# Validation set:
# Resize -> cache -> shuffle -> batch ->                      prefetch

# Test & Eval set:
# Resize -> batch

train_ds = train_ds.cache()
train_ds = train_ds.shuffle(buffer_size=1000)
train_ds = train_ds.map(load_image_train, num_parallel_calls=AUTOTUNE)
train_ds = train_ds.batch(batch_size=BATCH_SIZE)
train_ds = train_ds.repeat()
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)

val_ds = val_ds.map(load_image_test, num_parallel_calls=AUTOTUNE)
val_ds = val_ds.cache().batch(batch_size=BATCH_SIZE).prefetch(buffer_size=AUTOTUNE)

test_ds = test_ds.map(load_image_test, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.cache().batch(batch_size = BATCH_SIZE)
# runtime_test_ds = test_ds.cache().batch(batch_size=TEST_SIZE)

eval_ds = eval_ds.map(load_image_test, num_parallel_calls=AUTOTUNE)
eval_ds = eval_ds.batch(batch_size = BATCH_SIZE)

# %%
### Display images

# train_ds.skip(37)
for image_batch, mask_batch in val_ds.take(1):
  plt.figure(figsize=(10, 10))
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    image = image_batch[i]
    mask = mask_batch[i]
    plt.imshow(image)
    plt.imshow(tf.keras.preprocessing.image.array_to_img(mask), alpha=0.3, cmap='rainbow')
    plt.axis("off")
  break
# i = 0
# display([image_batch[i], mask_batch[i]])

# %% [markdown]
# ### Model Definition

# %%
tf.keras.backend.clear_session()

# Encoder
# base_model = tf.keras.applications.MobileNetV3Small(input_shape=[224, 224, 3], include_top=False, weights='imagenet')
base_model = tf.keras.applications.MobileNetV2(input_shape=[224, 224, 3], include_top=False)

# Extract the activations of these layers
layer_names = [
    'block_1_expand_relu',   # 64 x 64 x 96
    'block_3_expand_relu',   # 32 x 32 x 144
    'block_6_expand_relu',   # 16 x 16 x 192
    'block_13_expand_relu',  # 8  x 8  x 576
    'block_16_project',      # 4  x 4  x 320
]

layers = [base_model.get_layer(name).output for name in layer_names]

# # Create the feature extraction model
down_stack = tf.keras.Model(inputs=base_model.input, outputs=layers)
down_stack.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step

# %%
def deconv_block(filters, size, norm_type='batchnorm', dropout_rate = 0.5):
  '''
  Conv2DTranspose => Batchnorm => Dropout => Relu
  '''
  initializer = tf.random_normal_initializer(0., 0.02)
  # tf.keras.initializers.HeNormal(seed=None)
  result = tf.keras.Sequential()
  result.add(
      tf.keras.layers.Conv2DTranspose(filters, size, strides=2,
                                      padding='same',
                                      kernel_initializer=tf.keras.initializers.GlorotNormal(),
                                      use_bias=False))
  result.add(tf.keras.layers.BatchNormalization())
  # result.add(tf.keras.layers.Dropout(dropout_rate))
  result.add(tf.keras.layers.ReLU())
  return result

# %%
# Decoder
up_stack = [
    deconv_block(512, 3, dropout_rate = 0.5),  # 4x4 -> 8x8
    deconv_block(256, 3, dropout_rate = 0.4),  # 8x8 -> 16x16
    deconv_block(128, 3, dropout_rate = 0.3),  # 16x16 -> 32x32
    deconv_block(64, 3, dropout_rate = 0.2),   # 32x32 -> 64x64
]

# %%
def unet_model(output_channels):
  ''' Instantiate a new instance of UNet Model '''
  inputs = tf.keras.layers.Input(shape=[224, 224, 3])
  x = inputs

  # Downsampling through the model
  skips = down_stack(x)
  x = skips[-1]
  skips = reversed(skips[:-1])

  # Upsampling and establishing the skip connections
  for up, skip in zip(up_stack, skips):
    x = up(x)
    concat = tf.keras.layers.Concatenate()
    x = concat([x, skip])

  # This is the last layer of the model
  last = tf.keras.layers.Conv2DTranspose(
      output_channels, 3, strides=2,
      padding='same')  #64x64 -> 128x128

  x = last(x)

  return tf.keras.Model(inputs=inputs, outputs=x)

# %% [markdown]
# ### Visualisation functions

# %%
def create_mask(pred_mask):
  ''' Finds top prediction mask and returns it'''
  pred_mask = tf.argmax(pred_mask, axis=-1)
  pred_mask = pred_mask[..., tf.newaxis]
  return pred_mask[0]

# %%
def display(display_list, merge = False):
  '''
  Takes an array of images and plots them

  Args
  ----------
  display_list: list
    expecting [input, true mask, predicted mask]

  Returns
  ----------
  None, graph is displayed
  '''
  if not merge:
    plt.figure(figsize=(15, 15))

    title = ['Input Image', 'True Mask', 'Predicted Mask']

    for i in range(len(display_list)):
      plt.subplot(1, len(display_list), i+1)
      plt.title(title[i])
      plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]))
      plt.axis('off')
    plt.show()

  elif merge == True:
    plt.figure(figsize=(15, 15))

    plt.subplot(1, 3, 1)
    plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[0]))
    plt.axis('off')
    plt.subplot(1, 3, 2)
    plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[0]))
    plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[1]), alpha = 0.5)
    plt.axis('off')
    plt.subplot(1, 3, 3)
    plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[0]))
    plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[2]), alpha = 0.5)
    plt.axis('off')

# %%
def show_predictions(dataset=None, num=1, show_sample=False, merge=False):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  dataset (optional): tf.dataset object, defaults first image in testing set
  num (optional): int
  sample (optional): bool: if True, display prediction for sample image

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  batches = num//BATCH_SIZE + 1
  remainder = num%BATCH_SIZE
  if show_sample:
    display([sample_image, sample_mask, create_mask(model.predict(sample_image[tf.newaxis, ...]))], merge=merge) 
    return
  if dataset:
    for image, mask in dataset.take(batches):
      pred_mask = model.predict(image[remainder][tf.newaxis, ...])
    display([image[remainder], mask[remainder], create_mask(pred_mask)], merge=merge)
  else:
    for image, mask in test_ds.take(batches):
      pred_mask = model.predict(image[remainder][tf.newaxis, ...])
    display([image[remainder], mask[remainder], create_mask(pred_mask)], merge=merge)

for images, masks in val_ds.take(1):
  sample_image, sample_mask = images[5], masks[5] 

display([sample_image, sample_mask])

# %% [markdown]
# ### Shoreline Eval functions

# %%
def MODD2_shoreline_eval_single_image(gt_mask, pred_mask):

  '''
  Calculates the RMSE of horizon detection for a single image

  Args:
  ---------
  gt_mask: numpy.array (128, 128, 1)
  pred_mask: numpy.array (128, 128, 1)

  Returns:
  --------
  rmse: int
    (normalized) root mean square error of a single image
  '''

  HEIGHT = len(gt_mask)
  WIDTH = len(gt_mask[0, :])
  gt_len = 1

  diffs = np.empty(WIDTH)
  for i in range(WIDTH):
    # print(gt_mask[:, i])
    # print(pred_mask[:, i])
    for j, val in enumerate(gt_mask[:, i]):
      if val == 1:
        gt_len += 1
        break
    for k, val in enumerate(pred_mask[:, i]):
      if val == 1:
        break
    # if no detection along column, assume detection is at bottom of the image
    diffs[i] = abs(j - k)/HEIGHT
    # overflow occurs because of np division, shouldn't affect performance
    rmse = np.sqrt((sum(diffs)**2))/gt_len
  return rmse

# tic = time.perf_counter()
# gt_mask = sample_mask.numpy()
# pred_mask = create_mask(model.predict(sample_image[tf.newaxis, ...])).numpy()
# toc = time.perf_counter()
# print(f"preparing: {toc - tic:0.4f} seconds")

# tic = time.perf_counter()
# MODD2_shoreline_eval_single_image(gt_mask, pred_mask)
# toc = time.perf_counter()
# print(f"RMSE: {toc - tic:0.4f} seconds")

# %%
def MODD2_shoreline_eval(ds='test'):
  '''
  Returns score for the MODD2 evaluation of shoreline

  From MODD2 github page:
    For each pixel column in the full-sized image, a distance between water edge, 
    as given by the ground truth and as determined by the algorithm, is calculated. 
    These values are summarised into a single value by averaging across all 
    columns, frames and sequences.

  Args: 
  ----------
  ds: tf.dataset
    dataset object (either train_ds, val_ds, or test_ds)

  Returns:
  ----------
  (mean, std): tuple
    the mean and std for difference between prediction and gt
  '''
  if ds == 'test':
    ds_length = TEST_SIZE
    ds = test_ds
  elif ds == 'train':
    ds_length = TRAINSET_SIZE
    ds = train_ds
  elif ds == 'val':
    ds_length = VALSET_SIZE
    ds = val_ds
  elif ds == 'eval':
    ds_length = EVAL_SIZE
    ds = eval_ds
  else:
    print('Please input valid dataset name (either train, val, or test)')
    raise ValueError()

  num_batches = ds_length // BATCH_SIZE + 1

  # Loop through batches
  RMSEs = []
  for images, labels in tqdm(ds.take(num_batches)):
    preds = model.predict(images)
    # Loop through images within a batch:
    for i, label in enumerate(labels):
      # Have to convert to numpy, iterating through tensor is very slow
      gt_label = label.numpy()
      pred_label = create_mask(preds[i][tf.newaxis, ...]).numpy()

      RMSE = MODD2_shoreline_eval_single_image(gt_label, pred_label)
      RMSEs.append(RMSE)
  return RMSEs

# %% [markdown]
# ### Training

# %% [markdown]
# **Custom loss function**
#
# In the MasTr dataset, the edges of regions are labelled with class 4. The researchers took these regions as 'ambiguous' regions and ignore it.
#
# The loss function therefore need to ignore the pixels containing class 4
#
# Problem: losing a lot of pixels

# %%
UNLABELLED = 3.0

def custom_SparseCategoricalCrossentropy(y_true, y_pred):
  haslabel = tf.squeeze((y_true != UNLABELLED), axis=-1)
  y_true = tf.boolean_mask(y_true, haslabel)
  y_pred = tf.boolean_mask(y_pred, haslabel)

  return tf.keras.losses.sparse_categorical_crossentropy(y_true, y_pred, from_logits=True, axis=-1)


def custom_sigmoid_focal_crossentropy(y_true, y_pred):
  haslabel = tf.squeeze((y_true != UNLABELLED), axis=-1)
  y_true = tf.boolean_mask(y_true, haslabel)
  y_true = tf.squeeze(tf.one_hot(tf.cast(y_true, dtype='int32'), depth = 3, axis = 2))
  y_pred = tf.boolean_mask(y_pred, haslabel)

  return tfa.losses.sigmoid_focal_crossentropy(y_true, y_pred, from_logits=True)

# %%
def count_num_unlabelled():
  sum = 0
  for images, labels in val_ds.take(VALSET_SIZE//BATCH_SIZE+1):
    for image, y_true in zip(images, labels):
      y_true = y_true[tf.newaxis, ...]

      haslabel = tf.squeeze((y_true != UNLABELLED), axis=-1)
      y_true = tf.boolean_mask(y_true, haslabel)
      y_true = tf.squeeze(tf.one_hot(tf.cast(y_true, dtype='int32'), depth = 3, axis = 2))
      sum += 1-len(y_true)/(224*224)
  return sum/VALSET_SIZE

1 - count_num_unlabelled()
# Out:
# 0.986736462089535

# %% [markdown]
# **Callbacks**
#
# - `cp_callback`: saves the best checkpoint weight based on validation loss
# - `tensorboard_callback`: writes results to tensorboard
# - `rsme_callback`: computes rmse on eval and val set every 5 epochs, writes to tensorboard

# %%
# TENSORBOARD CALLBACK
# %load_ext tensorboard

# Clear any logs from previous runs
# !rm -rf ./logs/
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

checkpoint_path = "training_checkpoints/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

try:
  os.mkdir(checkpoint_path)
except:
  pass

# CHECKPOINT CALLBACK
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path+'2',
                                                 save_weights_only=True,
                                                 save_best_only = True,
                                                 monitor = 'val_accuracy',
                                                 verbose=1)

# RMSE CALLBACK
rmse_writer = tf.summary.create_file_writer(log_dir)

class RMSE_callback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs = None):
      if epoch%5 == 0:
        mean = np.mean(MODD2_shoreline_eval())
        mean_val = np.mean(MODD2_shoreline_eval('val'))
        with rmse_writer.as_default():
          tf.summary.scalar('RMSE_eval', mean, step=epoch)
          tf.summary.scalar('RMSE_val', mean_val, step=epoch)
        print('Test RMSE: {}'.format(mean))
        print('Val  RMSE: {}'.format(mean_val))

rmse_callback = RMSE_callback()

# %% [markdown]
# **Instantiate model or load model**

# %%
# Retrieve model from drive to cwd 
retrieve_index = 'dropout-1000'
filename = '224x224-' + retrieve_index + 'e.zip'
model_path = '/content/drive/MyDrive/project_online/saved_models/' + filename
# !unzip '$model_path' -d 'trained_model'

model = tf.keras.models.load_model('/content/trained_model/224x224-dropout-1000e', custom_objects={'custom_sigmoid_focal_crossentropy': custom_sigmoid_focal_crossentropy})

model.save_weights(checkpoint_path+ retrieve_index + 'e')
# Out:
# Archive:  /content/drive/MyDrive/project_online/saved_models/224x224-dropout-1000e.zip
#    creating: trained_model/224x224-dropout-1000e/
#    creating: trained_model/224x224-dropout-1000e/assets/
#   inflating: trained_model/224x224-dropout-1000e/saved_model.pb
#    creating: trained_model/224x224-dropout-1000e/variables/
#   inflating: trained_model/224x224-dropout-1000e/variables/variables.index
#   inflating: trained_model/224x224-dropout-1000e/variables/variables.data-00000-of-00001

# %%
model = unet_model(output_channels=N_CLASSES)
model.compile(optimizer=tf.keras.optimizers.RMSprop(),
              loss=custom_SparseCategoricalCrossentropy, #custom_sigmoid_focal_crossentropy,
              metrics=['accuracy'])

# %%
# Check that everything is loaded properlly
show_predictions(show_sample=True)

# %%
EPOCHS = 200
STEPS_PER_EPOCH = TRAINSET_SIZE // BATCH_SIZE
VALIDATION_STEPS = VALSET_SIZE // BATCH_SIZE

model_history_2 = model.fit(train_ds, epochs=EPOCHS,
                          steps_per_epoch=STEPS_PER_EPOCH,
                          callbacks=[cp_callback, tensorboard_callback],
                          validation_steps=VALIDATION_STEPS,
                          validation_data=val_ds)
# Out:
# Epoch 1/200
# 18/18 [==============================] - 26s 1s/step - loss: 0.0075 - accuracy: 0.9516 - val_loss: 0.0714 - val_accuracy: 0.9712
#
# Epoch 00001: val_accuracy did not improve from 0.97124
# Epoch 2/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0076 - accuracy: 0.9491 - val_loss: 0.0709 - val_accuracy: 0.9713
#
# Epoch 00002: val_accuracy improved from 0.97124 to 0.97130, saving model to training_checkpoints/cp.ckpt2
# Epoch 3/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0082 - accuracy: 0.9513 - val_loss: 0.0772 - val_accuracy: 0.9710
#
# Epoch 00003: val_accuracy did not improve from 0.97130
# Epoch 4/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0081 - accuracy: 0.9483 - val_loss: 0.0736 - val_accuracy: 0.9712
#
# Epoch 00004: val_accuracy did not improve from 0.97130
# Epoch 5/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0080 - accuracy: 0.9514 - val_loss: 0.0690 - val_accuracy: 0.9711
#
# Epoch 00005: val_accuracy did not improve from 0.97130
# Epoch 6/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0079 - accuracy: 0.9500 - val_loss: 0.0735 - val_accuracy: 0.9712
#
# Epoch 00006: val_accuracy did not improve from 0.97130
# Epoch 7/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0077 - accuracy: 0.9506 - val_loss: 0.0724 - val_accuracy: 0.9711
#
# Epoch 00007: val_accuracy did not improve from 0.97130
# Epoch 8/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0079 - accuracy: 0.9498 - val_loss: 0.0730 - val_accuracy: 0.9709
#
# Epoch 00008: val_accuracy did not improve from 0.97130
# Epoch 9/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0076 - accuracy: 0.9521 - val_loss: 0.0718 - val_accuracy: 0.9712
#
# Epoch 00009: val_accuracy did not improve from 0.97130
# Epoch 10/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0076 - accuracy: 0.9511 - val_loss: 0.0805 - val_accuracy: 0.9706
#
# Epoch 00010: val_accuracy did not improve from 0.97130
# Epoch 11/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0079 - accuracy: 0.9502 - val_loss: 0.0754 - val_accuracy: 0.9711
#
# Epoch 00011: val_accuracy did not improve from 0.97130
# Epoch 12/200
# 18/18 [==============================] - 22s 1s/step - loss: 0.0072 - accuracy: 0.9518 - val_loss: 0.0760 - val_accuracy: 0.9710
#
# Epoch 00012: val_accuracy did not improve from 0.97130
# Epoch 13/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0081 - accuracy: 0.9504 - val_loss: 0.0768 - val_accuracy: 0.9710
#
# Epoch 00013: val_accuracy did not improve from 0.97130
# Epoch 14/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0077 - accuracy: 0.9515 - val_loss: 0.0723 - val_accuracy: 0.9712
#
# Epoch 00014: val_accuracy did not improve from 0.97130
# Epoch 15/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0076 - accuracy: 0.9514 - val_loss: 0.0707 - val_accuracy: 0.9712
#
# Epoch 00015: val_accuracy did not improve from 0.97130
# Epoch 16/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0080 - accuracy: 0.9499 - val_loss: 0.0750 - val_accuracy: 0.9711
#
# Epoch 00016: val_accuracy did not improve from 0.97130
# Epoch 17/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0077 - accuracy: 0.9496 - val_loss: 0.0732 - val_accuracy: 0.9712
#
# Epoch 00017: val_accuracy did not improve from 0.97130
# Epoch 18/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0076 - accuracy: 0.9501 - val_loss: 0.0682 - val_accuracy: 0.9711
#
# Epoch 00018: val_accuracy did not improve from 0.97130
# Epoch 19/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0079 - accuracy: 0.9488 - val_loss: 0.0751 - val_accuracy: 0.9710
#
# Epoch 00019: val_accuracy did not improve from 0.97130
# Epoch 20/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0074 - accuracy: 0.9512 - val_loss: 0.0739 - val_accuracy: 0.9710
#
# Epoch 00020: val_accuracy did not improve from 0.97130
# Epoch 21/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0083 - accuracy: 0.9497 - val_loss: 0.0784 - val_accuracy: 0.9709
#
# Epoch 00021: val_accuracy did not improve from 0.97130
# Epoch 22/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0073 - accuracy: 0.9506 - val_loss: 0.0780 - val_accuracy: 0.9710
#
# Epoch 00022: val_accuracy did not improve from 0.97130
# Epoch 23/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0076 - accuracy: 0.9518 - val_loss: 0.0757 - val_accuracy: 0.9711
#
# Epoch 00023: val_accuracy did not improve from 0.97130
# Epoch 24/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0077 - accuracy: 0.9519 - val_loss: 0.0699 - val_accuracy: 0.9710
#
# Epoch 00024: val_accuracy did not improve from 0.97130
# Epoch 25/200
# 18/18 [==============================] - 22s 1s/step - loss: 0.0077 - accuracy: 0.9503 - val_loss: 0.0687 - val_accuracy: 0.9711
#
# Epoch 00025: val_accuracy did not improve from 0.97130
# Epoch 26/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0078 - accuracy: 0.9504 - val_loss: 0.0717 - val_accuracy: 0.9713
#
# Epoch 00026: val_accuracy did not improve from 0.97130
# Epoch 27/200
# 18/18 [==============================] - 25s 1s/step - loss: 0.0071 - accuracy: 0.9485 - val_loss: 0.0719 - val_accuracy: 0.9712
#
# Epoch 00027: val_accuracy did not improve from 0.97130
# Epoch 28/200
# 18/18 [==============================] - 22s 1s/step - loss: 0.0085 - accuracy: 0.9497 - val_loss: 0.0715 - val_accuracy: 0.9712
#
# Epoch 00028: val_accuracy did not improve from 0.97130
# Epoch 29/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0077 - accuracy: 0.9503 - val_loss: 0.0769 - val_accuracy: 0.9711
#
# Epoch 00029: val_accuracy did not improve from 0.97130
# Epoch 30/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0075 - accuracy: 0.9517 - val_loss: 0.0736 - val_accuracy: 0.9712
#
# Epoch 00030: val_accuracy did not improve from 0.97130
# Epoch 31/200
# 18/18 [==============================] - 24s 1s/step - loss: 0.0079 - accuracy: 0.9503 - val_loss: 0.0719 - val_accuracy: 0.9711
#
# Epoch 00031: val_accuracy did not improve from 0.97130
# Epoch 32/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0073 - accuracy: 0.9495 - val_loss: 0.0694 - val_accuracy: 0.9712
#
# Epoch 00032: val_accuracy did not improve from 0.97130
# Epoch 33/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0079 - accuracy: 0.9505 - val_loss: 0.0760 - val_accuracy: 0.9710
#
# Epoch 00033: val_accuracy did not improve from 0.97130
# Epoch 34/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0080 - accuracy: 0.9505 - val_loss: 0.0741 - val_accuracy: 0.9712
#
# Epoch 00034: val_accuracy did not improve from 0.97130
# Epoch 35/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0076 - accuracy: 0.9509 - val_loss: 0.0714 - val_accuracy: 0.9712
#
# Epoch 00035: val_accuracy did not improve from 0.97130
# Epoch 36/200
# 18/18 [==============================] - 22s 1s/step - loss: 0.0073 - accuracy: 0.9518 - val_loss: 0.0706 - val_accuracy: 0.9712
#
# Epoch 00036: val_accuracy did not improve from 0.97130
# Epoch 37/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0075 - accuracy: 0.9512 - val_loss: 0.0719 - val_accuracy: 0.9710
#
# Epoch 00037: val_accuracy did not improve from 0.97130
# Epoch 38/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0079 - accuracy: 0.9512 - val_loss: 0.0736 - val_accuracy: 0.9710
#
# Epoch 00038: val_accuracy did not improve from 0.97130
# Epoch 39/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0075 - accuracy: 0.9514 - val_loss: 0.0748 - val_accuracy: 0.9710
#
# Epoch 00039: val_accuracy did not improve from 0.97130
# Epoch 40/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0085 - accuracy: 0.9500 - val_loss: 0.0706 - val_accuracy: 0.9711
#
# Epoch 00040: val_accuracy did not improve from 0.97130
# Epoch 41/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0082 - accuracy: 0.9496 - val_loss: 0.0771 - val_accuracy: 0.9711
#
# Epoch 00041: val_accuracy did not improve from 0.97130
# Epoch 42/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0078 - accuracy: 0.9498 - val_loss: 0.0788 - val_accuracy: 0.9710
#
# Epoch 00042: val_accuracy did not improve from 0.97130
# Epoch 43/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0077 - accuracy: 0.9511 - val_loss: 0.0738 - val_accuracy: 0.9712
#
# Epoch 00043: val_accuracy did not improve from 0.97130
# Epoch 44/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0074 - accuracy: 0.9518 - val_loss: 0.0762 - val_accuracy: 0.9710
#
# Epoch 00044: val_accuracy did not improve from 0.97130
# Epoch 45/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0073 - accuracy: 0.9510 - val_loss: 0.0721 - val_accuracy: 0.9712
#
# Epoch 00045: val_accuracy did not improve from 0.97130
# Epoch 46/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0070 - accuracy: 0.9503 - val_loss: 0.0730 - val_accuracy: 0.9712
#
# Epoch 00046: val_accuracy did not improve from 0.97130
# Epoch 47/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0086 - accuracy: 0.9508 - val_loss: 0.0715 - val_accuracy: 0.9711
#
# Epoch 00047: val_accuracy did not improve from 0.97130
# Epoch 48/200
# 18/18 [==============================] - 22s 1s/step - loss: 0.0075 - accuracy: 0.9520 - val_loss: 0.0729 - val_accuracy: 0.9712
#
# Epoch 00048: val_accuracy did not improve from 0.97130
# Epoch 49/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0075 - accuracy: 0.9527 - val_loss: 0.0751 - val_accuracy: 0.9711
#
# Epoch 00049: val_accuracy did not improve from 0.97130
# Epoch 50/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0078 - accuracy: 0.9504 - val_loss: 0.0704 - val_accuracy: 0.9712
#
# Epoch 00050: val_accuracy did not improve from 0.97130
# Epoch 51/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0075 - accuracy: 0.9504 - val_loss: 0.0769 - val_accuracy: 0.9709
#
# Epoch 00051: val_accuracy did not improve from 0.97130
# Epoch 52/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0076 - accuracy: 0.9511 - val_loss: 0.0756 - val_accuracy: 0.9710
#
# Epoch 00052: val_accuracy did not improve from 0.97130
# Epoch 53/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0076 - accuracy: 0.9514 - val_loss: 0.0773 - val_accuracy: 0.9710
#
# Epoch 00053: val_accuracy did not improve from 0.97130
# Epoch 54/200
# 18/18 [==============================] - 24s 1s/step - loss: 0.0073 - accuracy: 0.9503 - val_loss: 0.0745 - val_accuracy: 0.9711
#
# Epoch 00054: val_accuracy did not improve from 0.97130
# Epoch 55/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0073 - accuracy: 0.9497 - val_loss: 0.0693 - val_accuracy: 0.9712
#
# Epoch 00055: val_accuracy did not improve from 0.97130
# Epoch 56/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0078 - accuracy: 0.9513 - val_loss: 0.0693 - val_accuracy: 0.9711
#
# Epoch 00056: val_accuracy did not improve from 0.97130
# Epoch 57/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0077 - accuracy: 0.9498 - val_loss: 0.0704 - val_accuracy: 0.9712
#
# Epoch 00057: val_accuracy did not improve from 0.97130
# Epoch 58/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0082 - accuracy: 0.9512 - val_loss: 0.0737 - val_accuracy: 0.9712
#
# Epoch 00058: val_accuracy did not improve from 0.97130
# Epoch 59/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0081 - accuracy: 0.9512 - val_loss: 0.0707 - val_accuracy: 0.9712
#
# Epoch 00059: val_accuracy did not improve from 0.97130
# Epoch 60/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0076 - accuracy: 0.9515 - val_loss: 0.0757 - val_accuracy: 0.9710
#
# Epoch 00060: val_accuracy did not improve from 0.97130
# Epoch 61/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0078 - accuracy: 0.9520 - val_loss: 0.0731 - val_accuracy: 0.9711
#
# Epoch 00061: val_accuracy did not improve from 0.97130
# Epoch 62/200
# 18/18 [==============================] - 22s 1s/step - loss: 0.0078 - accuracy: 0.9516 - val_loss: 0.0757 - val_accuracy: 0.9711
#
# Epoch 00062: val_accuracy did not improve from 0.97130
# Epoch 63/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0073 - accuracy: 0.9516 - val_loss: 0.0778 - val_accuracy: 0.9708
#
# Epoch 00063: val_accuracy did not improve from 0.97130
# Epoch 64/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0079 - accuracy: 0.9525 - val_loss: 0.0739 - val_accuracy: 0.9711
#
# Epoch 00064: val_accuracy did not improve from 0.97130
# Epoch 65/200
# 18/18 [==============================] - 22s 1s/step - loss: 0.0075 - accuracy: 0.9532 - val_loss: 0.0747 - val_accuracy: 0.9710
#
# Epoch 00065: val_accuracy did not improve from 0.97130
# Epoch 66/200
# 18/18 [==============================] - 23s 1s/step - loss: 0.0071 - accuracy: 0.9512 - val_loss: 0.0752 - val_accuracy: 0.9711
#
# Epoch 00066: val_accuracy did not improve from 0.97130
# Epoch 67/200
# 12/18 [===================>..........] - ETA: 7s - loss: 0.0078 - accuracy: 0.9512

# %%
model.save_weights(checkpoint_path+'600')

# %% [markdown]
# ### Experimental: unfreezing & training entire model

# %%
# EPOCHS = 5
# STEPS_PER_EPOCH = TRAINSET_SIZE // BATCH_SIZE
# VALIDATION_STEPS = VALSET_SIZE // BATCH_SIZE

# down_stack.trainable=True

# model.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=1e-6),
#               loss=custom_sigmoid_focal_crossentropy,
#               metrics=['accuracy'])

# model_history = model.fit(train_ds, epochs=EPOCHS,
#                           steps_per_epoch=STEPS_PER_EPOCH,
#                           validation_steps=VALIDATION_STEPS,
#                           validation_data=val_ds)

# %%
# %tensorboard --logdir logs/fit

# %%
# Load best model
# model.save_weights(checkpoint_path+'1300e')
model.load_weights(checkpoint_path+'2')

# %%
# Calculate RMSEs
RMSEs_test, RMSEs_val, RMSEs_train, RMSEs_eval = 0, 0, 0, 0

RMSEs_test = MODD2_shoreline_eval()

mean = np.mean(RMSEs_test)
std = np.std(RMSEs_test)
print(mean, std)
# 0.01879525364004115 0.025340108952624577. (0.013802) #1239 

# 200e: 1452
# 400e: 1346 
# 600e: 1483
# Out:
# HBox(children=(FloatProgress(value=0.0, max=21.0), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:35: RuntimeWarning: overflow encountered in double_scalars
# 0.01482552591971859 0.019605597652799907

# %%
# Calculate RMSEs
RMSEs_eval = MODD2_shoreline_eval('eval')

mean = np.mean(RMSEs_eval)
std = np.std(RMSEs_eval)
print(mean, std)
# 0.025352097800063183 0.031343618588398944
# Out:
# HBox(children=(FloatProgress(value=0.0, max=183.0), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:35: RuntimeWarning: overflow encountered in double_scalars
# 0.012836116223670943 0.013141670920133651

# %%
RMSEs_val = MODD2_shoreline_eval('val')

mean = np.mean(RMSEs_val)
std = np.std(RMSEs_val)
print(mean, std)

# 0.01081862798777507 0.011286257064264645
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:35: RuntimeWarning: overflow encountered in double_scalars
# 0.004983049361480958 0.0023602077551249435

# %%
RMSEs_train = MODD2_shoreline_eval('train')

mean = np.mean(RMSEs_train)
std = np.std(RMSEs_train)
print(mean, std)
# 0.010701362492558989 0.07869251732263077
# Out:
# HBox(children=(FloatProgress(value=0.0, max=38.0), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:35: RuntimeWarning: overflow encountered in double_scalars
# 0.012441150529511325 0.013295066262898069

# %% [markdown]
# ### Score Summary

# %%
list_summary = []

list_summary.append([TRAINSET_SIZE, np.mean(RMSEs_train), np.std(RMSEs_train), np.mean(RMSEs_train) * 958])
list_summary.append([VALSET_SIZE, np.mean(RMSEs_val), np.std(RMSEs_val), np.mean(RMSEs_val) * 958])
list_summary.append([TEST_SIZE, np.mean(RMSEs_test), np.std(RMSEs_test), np.mean(RMSEs_test) * 958])
list_summary.append([EVAL_SIZE, np.mean(RMSEs_eval), np.std(RMSEs_eval), np.mean(RMSEs_eval) * 958])


df_summary = pd.DataFrame(data=list_summary, columns=['no.imgs', 'mean', 'std', 'mean-px'], index=['train', 'val', 'test', 'eval'])

df_summary
# Out:
#        no.imgs      mean       std    mean-px
# train     1192  0.000000  0.000000   0.000000
# val        133  0.000000  0.000000   0.000000
# test      1292  0.010898  0.010703  10.439974
# eval     11703  0.000000  0.000000   0.000000

# %%
# Test images
# 27_128 (reflection)         take(3)
# 27_256 (building)           take(5)
# 27_384 (big wall right)     take(7)
# 27_448 (big wall mid)       take(8)
# 27_512 (big wall left)      take(9)
# --------------------------- (total 671 images)
# 28_33 (standard)            take(12)
# 28_417 (wall mid)           take(18)
# 28_609 (hazy)               take(21)

# %%
index = 10

# test_ds.skip(6)
for image, mask in test_ds.take(7):
  display_image, display_mask = image[index], mask[index]

pred_mask = model.predict(display_image[tf.newaxis, ...])
pred_mask = create_mask(pred_mask)
display([display_image, display_mask, pred_mask])

# %% [markdown]
# ### Export detection results
# ```
# Make folders
# For each image, decide which folder it is
#   Detect
#   Resize
#   Save - filename_pred.png
#
# zip and save to google drive
# ```

# %% [markdown]
# **Export Model Checkpoint**

# %%
result_dir = '/content/results'
sequence_dirs = []

# Make folders
try:
  os.mkdir(os.path.join(os.getcwd(), 'results'))
  for i in range(28):
    sequence_dir = os.path.join(result_dir, f'seq{i+1:02d}')
    output_dir = os.path.join(sequence_dir, 'Unet')
    sequence_dirs.append(sequence_dir)
    os.mkdir(sequence_dir)
    os.mkdir(output_dir)
except:
  print('error raised')
# Out:
# error raised

# %%
eval_dir = '/content/eval_data'
eval_image_dir = os.path.join(eval_dir, 'images')

for i in range(28):
  seq_foldername = f'seq{i+1:02d}'
  seq_filepath = os.path.join(eval_image_dir, seq_foldername)
  print(f'detecting results for {seq_foldername}...')
  for image in tqdm(sorted(os.listdir(seq_filepath))):
    if image.endswith('.jpg'):
      filename = image[:-4]
      filepath = os.path.join(seq_filepath, image)
      out_filename = filename + '_pred'
      out_filepath = os.path.join(result_dir, seq_foldername, out_filename + '.png')

      image = pimage.open(filepath)
      image = image.resize((224, 224))
      image_np = np.asarray(image)/255
      image_tensor = tf.convert_to_tensor(image_np)

      pred_mask = model.predict(image_tensor[tf.newaxis, ...])
      pred_mask = tf.squeeze(create_mask(pred_mask))
      
      pred_mask_np = pred_mask.numpy()
      pred_mask_np = np.repeat(np.expand_dims(pred_mask_np, axis=2), 3, axis=2)
      pred_mask_image = pimage.fromarray(pred_mask_np.astype(np.uint8), 'RGB')
      pred_mask_image = pred_mask_image.resize((512, 384))
      # print(out_filepath)
      pred_mask_image.save(out_filepath)
# Out:
# detecting results for seq01...
# HBox(children=(FloatProgress(value=0.0, max=551.0), HTML(value='')))
# detecting results for seq02...
# HBox(children=(FloatProgress(value=0.0, max=471.0), HTML(value='')))
# detecting results for seq03...
# HBox(children=(FloatProgress(value=0.0, max=251.0), HTML(value='')))
# detecting results for seq04...
# HBox(children=(FloatProgress(value=0.0, max=241.0), HTML(value='')))
# detecting results for seq05...
# HBox(children=(FloatProgress(value=0.0, max=901.0), HTML(value='')))
# detecting results for seq06...
# HBox(children=(FloatProgress(value=0.0, max=821.0), HTML(value='')))
# detecting results for seq07...
# HBox(children=(FloatProgress(value=0.0, max=791.0), HTML(value='')))
# detecting results for seq08...
# HBox(children=(FloatProgress(value=0.0, max=671.0), HTML(value='')))
# detecting results for seq09...
# HBox(children=(FloatProgress(value=0.0, max=181.0), HTML(value='')))
# detecting results for seq10...
# HBox(children=(FloatProgress(value=0.0, max=111.0), HTML(value='')))
# detecting results for seq11...
# HBox(children=(FloatProgress(value=0.0, max=281.0), HTML(value='')))
# detecting results for seq12...
# HBox(children=(FloatProgress(value=0.0, max=201.0), HTML(value='')))
# detecting results for seq13...
# HBox(children=(FloatProgress(value=0.0, max=211.0), HTML(value='')))
# detecting results for seq14...
# HBox(children=(FloatProgress(value=0.0, max=176.0), HTML(value='')))
# detecting results for seq15...
# HBox(children=(FloatProgress(value=0.0, max=416.0), HTML(value='')))
# detecting results for seq16...
# HBox(children=(FloatProgress(value=0.0, max=661.0), HTML(value='')))
# detecting results for seq17...
# HBox(children=(FloatProgress(value=0.0, max=311.0), HTML(value='')))
# detecting results for seq18...
# HBox(children=(FloatProgress(value=0.0, max=301.0), HTML(value='')))
# detecting results for seq19...
# HBox(children=(FloatProgress(value=0.0, max=521.0), HTML(value='')))
# detecting results for seq20...
# HBox(children=(FloatProgress(value=0.0, max=521.0), HTML(value='')))
# detecting results for seq21...
# HBox(children=(FloatProgress(value=0.0, max=296.0), HTML(value='')))
# detecting results for seq22...
# HBox(children=(FloatProgress(value=0.0, max=161.0), HTML(value='')))
# detecting results for seq23...
# HBox(children=(FloatProgress(value=0.0, max=291.0), HTML(value='')))
# detecting results for seq24...
# HBox(children=(FloatProgress(value=0.0, max=341.0), HTML(value='')))
# detecting results for seq25...
# HBox(children=(FloatProgress(value=0.0, max=561.0), HTML(value='')))
# detecting results for seq26...
# HBox(children=(FloatProgress(value=0.0, max=171.0), HTML(value='')))
# detecting results for seq27...
# HBox(children=(FloatProgress(value=0.0, max=621.0), HTML(value='')))
# detecting results for seq28...
# HBox(children=(FloatProgress(value=0.0, max=671.0), HTML(value='')))

# %%
# Zip and save to drive 
# %%bash
#   adding: seq27/00011357L_pred.png (deflated 26%)
#   adding: seq27/00011230L_pred.png (deflated 61%)
#   adding: seq27/00011754L_pred.png (deflated 66%)
# ...
#   adding: seq02/00025663L_pred.png (deflated 49%)
#   adding: seq02/00025221L_pred.png (deflated 56%)
#   adding: seq02/00025400L_pred.png (deflated 42%)
#   adding: seq02/00025385L_pred.png (deflated 42%)
#   adding: seq02/00025226L_pred.png (deflated 59%)
#   adding: seq02/00025484L_pred.png (deflated 49%)
#   adding: seq02/00025522L_pred.png (deflated 53%)
#   adding: seq02/00025463L_pred.png (deflated 48%)
#   adding: seq02/00025474L_pred.png (deflated 45%)
#   adding: seq02/00025633L_pred.png (deflated 48%)
#   adding: seq02/00025427L_pred.png (deflated 40%)
#   adding: seq02/00025322L_pred.png (deflated 46%)
#   adding: seq02/00025408L_pred.png (deflated 45%)
#   adding: seq02/00025518L_pred.png (deflated 51%)
#   adding: seq02/00025376L_pred.png (deflated 37%)
#   adding: seq02/00025203L_pred.png (deflated 57%)
#   adding: seq02/00025321L_pred.png (deflated 45%)
#   adding: seq02/00025241L_pred.png (deflated 57%)
#   adding: seq02/00025312L_pred.png (deflated 48%)
#   adding: seq02/00025293L_pred.png (deflated 52%)
#   adding: seq02/00025290L_pred.png (deflated 57%)
#   adding: seq02/00025421L_pred.png (deflated 46%)
#   adding: seq02/00025271L_pred.png (deflated 57%)
#   adding: seq02/00025553L_pred.png (deflated 48%)
#   adding: seq02/00025291L_pred.png (deflated 55%)
#   adding: seq02/00025355L_pred.png (deflated 40%)
#   adding: seq02/00025572L_pred.png (deflated 48%)
#   adding: seq02/00025247L_pred.png (deflated 56%)
#   adding: seq02/00025327L_pred.png (deflated 45%)
#   adding: seq02/00025276L_pred.png (deflated 54%)
#   adding: seq02/00025352L_pred.png (deflated 39%)
#   adding: seq02/00025627L_pred.png (deflated 44%)
#   adding: seq02/00025210L_pred.png (deflated 57%)
#   adding: seq02/00025646L_pred.png (deflated 49%)
#   adding: seq02/00025564L_pred.png (deflated 49%)
#   adding: seq02/00025655L_pred.png (deflated 36%)
#   adding: seq02/00025229L_pred.png (deflated 58%)
#   adding: seq02/00025222L_pred.png (deflated 57%)
#   adding: seq02/00025307L_pred.png (deflated 48%)
#   adding: seq02/00025603L_pred.png (deflated 47%)
#   adding: seq02/00025451L_pred.png (deflated 49%)
#   adding: seq02/00025228L_pred.png (deflated 56%)
#   adding: seq02/00025496L_pred.png (deflated 49%)
#   adding: seq02/00025244L_pred.png (deflated 55%)
#   adding: seq02/00025364L_pred.png (deflated 40%)
#   adding: seq02/00025238L_pred.png (deflated 56%)
#   adding: seq02/00025248L_pred.png (deflated 55%)
#   adding: seq02/00025292L_pred.png (deflated 52%)
#   adding: seq02/00025541L_pred.png (deflated 46%)
#   adding: seq02/00025280L_pred.png (deflated 55%)
#   adding: seq02/00025599L_pred.png (deflated 44%)
#   adding: seq02/00025669L_pred.png (deflated 42%)
#   adding: seq02/00025351L_pred.png (deflated 40%)
#   adding: seq02/00025517L_pred.png (deflated 51%)
#   adding: seq02/00025461L_pred.png (deflated 48%)
#   adding: seq02/00025662L_pred.png (deflated 48%)
#   adding: seq02/00025595L_pred.png (deflated 48%)
#   adding: seq02/00025441L_pred.png (deflated 44%)
#   adding: seq02/00025628L_pred.png (deflated 46%)
#   adding: seq02/00025505L_pred.png (deflated 49%)
#   adding: seq02/00025475L_pred.png (deflated 48%)
#   adding: seq02/00025367L_pred.png (deflated 41%)
#   adding: seq02/00025556L_pred.png (deflated 49%)
#   adding: seq02/00025374L_pred.png (deflated 38%)
#   adding: seq02/00025270L_pred.png (deflated 56%)
#   adding: seq02/00025450L_pred.png (deflated 48%)
#   adding: seq02/00025588L_pred.png (deflated 49%)
#   adding: seq02/00025348L_pred.png (deflated 39%)
#   adding: seq02/00025540L_pred.png (deflated 48%)
#   adding: seq02/00025411L_pred.png (deflated 42%)
#   adding: seq02/00025429L_pred.png (deflated 39%)
#   adding: seq02/00025283L_pred.png (deflated 58%)
#   adding: seq02/00025538L_pred.png (deflated 48%)
#   adding: seq02/00025358L_pred.png (deflated 40%)
#   adding: seq02/00025414L_pred.png (deflated 39%)
#   adding: seq02/00025530L_pred.png (deflated 52%)
#   adding: seq02/00025516L_pred.png (deflated 52%)
#   adding: seq02/00025645L_pred.png (deflated 47%)
#   adding: seq02/00025269L_pred.png (deflated 55%)
#   adding: seq02/00025577L_pred.png (deflated 49%)
#   adding: seq02/00025527L_pred.png (deflated 50%)
#   adding: seq02/00025356L_pred.png (deflated 41%)
#   adding: seq02/00025439L_pred.png (deflated 47%)
#   adding: seq02/00025602L_pred.png (deflated 48%)
#   adding: seq02/00025578L_pred.png (deflated 49%)
#   adding: seq02/00025382L_pred.png (deflated 40%)
#   adding: seq02/00025422L_pred.png (deflated 44%)
#   adding: seq02/00025394L_pred.png (deflated 46%)
#   adding: seq02/00025651L_pred.png (deflated 48%)
#   adding: seq02/00025523L_pred.png (deflated 51%)
#   adding: seq02/00025507L_pred.png (deflated 50%)
#   adding: seq02/00025467L_pred.png (deflated 48%)
#   adding: seq02/00025598L_pred.png (deflated 47%)
#   adding: seq02/00025231L_pred.png (deflated 58%)
#   adding: seq02/00025289L_pred.png (deflated 56%)
#   adding: seq02/00025446L_pred.png (deflated 46%)
#   adding: seq02/00025597L_pred.png (deflated 43%)
#   adding: seq02/00025214L_pred.png (deflated 56%)
#   adding: seq02/00025202L_pred.png (deflated 56%)
#   adding: seq02/00025499L_pred.png (deflated 51%)
#   adding: seq02/00025208L_pred.png (deflated 58%)
#   adding: seq02/00025440L_pred.png (deflated 46%)
#   adding: seq02/00025344L_pred.png (deflated 40%)
#   adding: seq02/00025418L_pred.png (deflated 42%)
#   adding: seq02/00025308L_pred.png (deflated 49%)
#   adding: seq02/00025592L_pred.png (deflated 49%)
#   adding: seq02/00025448L_pred.png (deflated 47%)
#   adding: seq02/00025237L_pred.png (deflated 56%)
#   adding: seq02/00025466L_pred.png (deflated 50%)
#   adding: seq02/00025295L_pred.png (deflated 50%)
#   adding: seq02/00025274L_pred.png (deflated 56%)
#   adding: seq02/00025207L_pred.png (deflated 58%)
#   adding: seq02/00025323L_pred.png (deflated 45%)
#   adding: seq02/00025557L_pred.png (deflated 49%)
#   adding: seq02/00025491L_pred.png (deflated 51%)
#   adding: seq02/00025253L_pred.png (deflated 55%)
#   adding: seq02/00025477L_pred.png (deflated 46%)
#   adding: seq02/00025548L_pred.png (deflated 48%)
#   adding: seq02/00025442L_pred.png (deflated 42%)
#   adding: seq02/00025206L_pred.png (deflated 57%)
#   adding: seq02/00025316L_pred.png (deflated 48%)
#   adding: seq02/00025434L_pred.png (deflated 39%)
#   adding: seq02/00025612L_pred.png (deflated 47%)
#   adding: seq02/00025263L_pred.png (deflated 55%)
#   adding: seq02/00025266L_pred.png (deflated 56%)
#   adding: seq02/00025329L_pred.png (deflated 44%)
#   adding: seq02/00025478L_pred.png (deflated 48%)
#   adding: seq02/00025391L_pred.png (deflated 43%)
#   adding: seq02/00025638L_pred.png (deflated 47%)
#   adding: seq02/00025255L_pred.png (deflated 56%)
#   adding: seq02/00025670L_pred.png (deflated 42%)
#   adding: seq02/00025204L_pred.png (deflated 58%)
#   adding: seq02/00025384L_pred.png (deflated 42%)
#   adding: seq02/00025464L_pred.png (deflated 49%)
#   adding: seq02/00025539L_pred.png (deflated 48%)
#   adding: seq02/00025310L_pred.png (deflated 49%)
#   adding: seq02/00025403L_pred.png (deflated 41%)
#   adding: seq02/00025412L_pred.png (deflated 40%)
#   adding: seq02/00025246L_pred.png (deflated 55%)
#   adding: seq02/00025620L_pred.png (deflated 50%)
#   adding: seq02/00025576L_pred.png (deflated 49%)
#   adding: seq02/00025330L_pred.png (deflated 44%)
#   adding: seq02/00025552L_pred.png (deflated 48%)
#   adding: seq02/00025489L_pred.png (deflated 50%)
#   adding: seq02/00025581L_pred.png (deflated 45%)
#   adding: seq02/00025569L_pred.png (deflated 47%)
#   adding: seq02/00025667L_pred.png (deflated 44%)
#   adding: seq02/00025584L_pred.png (deflated 48%)
#   adding: seq02/00025216L_pred.png (deflated 56%)
#   adding: seq02/00025560L_pred.png (deflated 50%)
#   adding: seq02/00025561L_pred.png (deflated 48%)
#   adding: seq02/00025235L_pred.png (deflated 57%)
#   adding: seq02/00025298L_pred.png (deflated 49%)
#   adding: seq02/00025250L_pred.png (deflated 56%)
#   adding: seq02/00025639L_pred.png (deflated 46%)
#   adding: seq02/00025594L_pred.png (deflated 47%)
#   adding: seq02/00025398L_pred.png (deflated 41%)
#   adding: seq02/00025267L_pred.png (deflated 56%)
#   adding: seq02/00025534L_pred.png (deflated 48%)
#   adding: seq02/00025392L_pred.png (deflated 40%)
#   adding: seq02/00025635L_pred.png (deflated 49%)
#   adding: seq02/00025607L_pred.png (deflated 47%)
#   adding: seq02/00025619L_pred.png (deflated 46%)
#   adding: seq02/00025570L_pred.png (deflated 47%)
#   adding: seq02/00025287L_pred.png (deflated 55%)
#   adding: seq02/00025606L_pred.png (deflated 48%)
#   adding: seq02/00025254L_pred.png (deflated 56%)
#   adding: seq02/00025533L_pred.png (deflated 48%)
#   adding: seq02/00025565L_pred.png (deflated 48%)
#   adding: seq02/00025490L_pred.png (deflated 50%)
#   adding: seq02/00025200L_pred.png (deflated 56%)
#   adding: seq02/00025665L_pred.png (deflated 48%)
#   adding: seq02/00025390L_pred.png (deflated 44%)
#   adding: seq02/00025417L_pred.png (deflated 41%)
#   adding: seq02/00025632L_pred.png (deflated 50%)
#   adding: seq02/00025454L_pred.png (deflated 49%)
#   adding: seq02/00025550L_pred.png (deflated 48%)
#   adding: seq02/00025502L_pred.png (deflated 49%)
#   adding: seq02/00025236L_pred.png (deflated 57%)
#   adding: seq02/00025436L_pred.png (deflated 41%)
#   adding: seq02/00025397L_pred.png (deflated 38%)
#   adding: seq02/00025609L_pred.png (deflated 46%)
#   adding: seq02/00025219L_pred.png (deflated 57%)
#   adding: seq02/00025610L_pred.png (deflated 48%)
#   adding: seq02/00025396L_pred.png (deflated 45%)
#   adding: seq02/00025642L_pred.png (deflated 49%)
#   adding: seq02/00025212L_pred.png (deflated 55%)
#   adding: seq02/00025303L_pred.png (deflated 50%)
#   adding: seq02/00025614L_pred.png (deflated 48%)
#   adding: seq02/00025549L_pred.png (deflated 50%)
#   adding: seq02/00025304L_pred.png (deflated 51%)
#   adding: seq02/00025409L_pred.png (deflated 46%)
#   adding: seq02/00025370L_pred.png (deflated 42%)
#   adding: seq02/00025419L_pred.png (deflated 46%)
#   adding: seq02/00025209L_pred.png (deflated 60%)
#   adding: seq02/00025245L_pred.png (deflated 56%)
#   adding: seq02/00025324L_pred.png (deflated 46%)
#   adding: seq02/00025445L_pred.png (deflated 46%)
#   adding: seq02/00025438L_pred.png (deflated 45%)
#   adding: seq02/00025611L_pred.png (deflated 49%)
#   adding: seq02/00025495L_pred.png (deflated 49%)
#   adding: seq02/00025342L_pred.png (deflated 43%)
#   adding: seq02/00025483L_pred.png (deflated 50%)
#   adding: seq02/00025640L_pred.png (deflated 47%)
#   adding: seq02/00025359L_pred.png (deflated 40%)
#   adding: seq02/00025257L_pred.png (deflated 55%)
#   adding: seq02/00025240L_pred.png (deflated 56%)
#   adding: seq02/00025319L_pred.png (deflated 46%)
#   adding: seq02/00025361L_pred.png (deflated 41%)
#   adding: seq02/00025383L_pred.png (deflated 41%)
#   adding: seq02/00025320L_pred.png (deflated 47%)
#   adding: seq02/00025520L_pred.png (deflated 50%)
#   adding: seq02/00025544L_pred.png (deflated 48%)
#   adding: seq02/00025249L_pred.png (deflated 55%)
#   adding: seq02/00025529L_pred.png (deflated 51%)
#   adding: seq02/00025334L_pred.png (deflated 45%)
#   adding: seq02/00025424L_pred.png (deflated 47%)
#   adding: seq02/00025580L_pred.png (deflated 48%)
#   adding: seq02/00025537L_pred.png (deflated 47%)
#   adding: seq02/00025242L_pred.png (deflated 56%)
#   adding: seq02/00025252L_pred.png (deflated 56%)
#   adding: seq02/00025420L_pred.png (deflated 46%)
#   adding: seq02/00025300L_pred.png (deflated 49%)
#   adding: seq02/00025282L_pred.png (deflated 57%)
#   adding: seq02/00025227L_pred.png (deflated 56%)
#   adding: seq02/00025217L_pred.png (deflated 59%)
#   adding: seq02/00025215L_pred.png (deflated 56%)
#   adding: seq02/00025624L_pred.png (deflated 47%)
#   adding: seq02/00025297L_pred.png (deflated 49%)
#   adding: seq02/00025604L_pred.png (deflated 48%)
#   adding: seq02/00025239L_pred.png (deflated 57%)
#   adding: seq02/00025311L_pred.png (deflated 49%)
#   adding: seq02/00025494L_pred.png (deflated 51%)
#   adding: seq02/00025354L_pred.png (deflated 39%)
#   adding: seq02/00025362L_pred.png (deflated 40%)
#   adding: seq02/00025405L_pred.png (deflated 44%)
#   adding: seq02/00025309L_pred.png (deflated 50%)
#   adding: seq02/00025457L_pred.png (deflated 48%)
#   adding: seq02/00025372L_pred.png (deflated 40%)
#   adding: seq02/00025582L_pred.png (deflated 49%)
#   adding: seq02/00025462L_pred.png (deflated 48%)
#   adding: seq02/00025504L_pred.png (deflated 48%)
#   adding: seq02/00025230L_pred.png (deflated 59%)
#   adding: seq02/00025459L_pred.png (deflated 48%)
#   adding: seq02/00025500L_pred.png (deflated 50%)
#   adding: seq02/00025460L_pred.png (deflated 48%)
#   adding: seq02/00025380L_pred.png (deflated 41%)
#   adding: seq02/00025554L_pred.png (deflated 49%)
#   adding: seq02/00025608L_pred.png (deflated 44%)
#   adding: seq02/00025256L_pred.png (deflated 56%)
#   adding: seq02/00025524L_pred.png (deflated 50%)
#   adding: seq02/00025482L_pred.png (deflated 53%)
#   adding: seq02/00025659L_pred.png (deflated 37%)
#   adding: seq02/00025360L_pred.png (deflated 42%)
#   adding: seq02/00025433L_pred.png (deflated 41%)
#   adding: seq02/00025357L_pred.png (deflated 42%)
#   adding: seq02/00025525L_pred.png (deflated 50%)
#   adding: seq02/00025590L_pred.png (deflated 49%)
#   adding: seq02/00025413L_pred.png (deflated 37%)
#   adding: seq02/00025379L_pred.png (deflated 37%)
#   adding: seq02/00025532L_pred.png (deflated 47%)
#   adding: seq02/00025425L_pred.png (deflated 47%)
#   adding: seq02/00025515L_pred.png (deflated 50%)
#   adding: seq02/00025485L_pred.png (deflated 49%)
#   adding: seq02/00025487L_pred.png (deflated 50%)
#   adding: seq02/00025416L_pred.png (deflated 40%)
#   adding: seq02/00025317L_pred.png (deflated 48%)
#   adding: seq02/00025386L_pred.png (deflated 41%)
#   adding: seq02/00025521L_pred.png (deflated 49%)
#   adding: seq02/00025325L_pred.png (deflated 45%)
#   adding: seq02/00025613L_pred.png (deflated 45%)
#   adding: seq02/Unet/ (stored 0%)
#   adding: seq02/00025649L_pred.png (deflated 47%)
#   adding: seq02/00025652L_pred.png (deflated 48%)
#   adding: seq02/00025656L_pred.png (deflated 35%)
#   adding: seq02/00025264L_pred.png (deflated 55%)
#   adding: seq02/00025284L_pred.png (deflated 57%)
#   adding: seq02/00025616L_pred.png (deflated 47%)
#   adding: seq02/00025305L_pred.png (deflated 48%)
#   adding: seq02/00025622L_pred.png (deflated 47%)
#   adding: seq02/00025301L_pred.png (deflated 48%)
#   adding: seq02/00025511L_pred.png (deflated 50%)
#   adding: seq02/00025279L_pred.png (deflated 54%)
#   adding: seq02/00025657L_pred.png (deflated 33%)
#   adding: seq02/00025341L_pred.png (deflated 43%)
#   adding: seq02/00025501L_pred.png (deflated 47%)
#   adding: seq02/00025294L_pred.png (deflated 49%)
#   adding: seq02/00025593L_pred.png (deflated 48%)
#   adding: seq02/00025339L_pred.png (deflated 42%)
#   adding: seq02/00025423L_pred.png (deflated 47%)
#   adding: seq02/00025623L_pred.png (deflated 48%)
#   adding: seq02/00025432L_pred.png (deflated 40%)
#   adding: seq02/00025567L_pred.png (deflated 47%)
#   adding: seq02/00025558L_pred.png (deflated 49%)
#   adding: seq02/00025302L_pred.png (deflated 47%)
#   adding: seq02/00025629L_pred.png (deflated 44%)
#   adding: seq02/00025275L_pred.png (deflated 55%)
#   adding: seq02/00025566L_pred.png (deflated 49%)
#   adding: seq02/00025260L_pred.png (deflated 54%)
#   adding: seq02/00025568L_pred.png (deflated 45%)
#   adding: seq02/00025664L_pred.png (deflated 49%)
#   adding: seq02/00025470L_pred.png (deflated 49%)
#   adding: seq02/00025426L_pred.png (deflated 43%)
#   adding: seq02/00025497L_pred.png (deflated 49%)
#   adding: seq02/00025437L_pred.png (deflated 45%)
#   adding: seq02/00025381L_pred.png (deflated 39%)
#   adding: seq02/00025428L_pred.png (deflated 36%)
#   adding: seq02/00025333L_pred.png (deflated 43%)
#   adding: seq02/00025224L_pred.png (deflated 56%)
#   adding: seq02/00025648L_pred.png (deflated 49%)
#   adding: seq02/00025615L_pred.png (deflated 47%)
#   adding: seq02/00025407L_pred.png (deflated 46%)
#   adding: seq02/00025555L_pred.png (deflated 48%)
#   adding: seq02/00025306L_pred.png (deflated 49%)
#   adding: seq02/00025318L_pred.png (deflated 44%)
#   adding: seq02/00025508L_pred.png (deflated 49%)
#   adding: seq02/00025331L_pred.png (deflated 44%)
#   adding: seq02/00025353L_pred.png (deflated 38%)
#   adding: seq02/00025211L_pred.png (deflated 56%)
#   adding: seq02/00025543L_pred.png (deflated 48%)

# %%
# !cp 'results/Results_SNet_baseline_600e.zip' '/content/drive/My Drive/project_online/'

# %% [markdown]
# ## Export model

# %%
out_filepath = 'SNet_baseline_600e'
out_zipfile = out_filepath + '.zip'

# %%
model.save(filepath=out_filepath)
# Out:
# INFO:tensorflow:Assets written to: SNet_baseline_600e/assets

# %%
out_filepath = 'SNet_baseline_600e'
out_zipfile = out_filepath + '.zip'
# !zip -r '$out_zipfile' '$out_filepath' -x '.*' -x '__MACOSX'
# Out:
#   adding: SNet_baseline_600e/ (stored 0%)
#   adding: SNet_baseline_600e/variables/ (stored 0%)
#   adding: SNet_baseline_600e/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: SNet_baseline_600e/variables/variables.index (deflated 76%)
#   adding: SNet_baseline_600e/saved_model.pb (deflated 92%)
#   adding: SNet_baseline_600e/assets/ (stored 0%)
